# %%
# !which pip
# Out:
# /home/virk/devs/WorkProjects/PGI/pgi_env/bin/pip

# %%
# !pip install fsleyes
# Out:
# ...
#      |████████████████████████████████| 40.4 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 66.0 MB 9.2 MB/s
# ...
#      |████████████████████████████████| 104 kB 83.1 MB/s
# ...
#      |████████████████████████████████| 111 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 2.4 MB 118.4 MB/s
# ...
#      |████████████████████████████████| 125 kB 124.9 MB/s
# ...
#   ERROR: Command errored out with exit status 1:
# ...

# %%
# %gui wx

# %%
import fsleyes
overlayList, displayCtx, frame = fsleyes.embed()
frame.Show()
# Out:
# ERROR:tornado.application:Exception in callback functools.partial(<function Kernel.enter_eventloop.<locals>.advance_eventloop at 0x7fd57cfb5ca0>)
# Traceback (most recent call last):
#   File "/home/virk/devs/WorkProjects/PGI/pgi_env/lib/python3.8/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/virk/devs/WorkProjects/PGI/pgi_env/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 401, in advance_eventloop
#     eventloop(self)
#   File "/home/virk/devs/WorkProjects/PGI/pgi_env/lib/python3.8/site-packages/ipykernel/eventloops.py", line 152, in loop_wx
#     import wx
# ModuleNotFoundError: No module named 'wx'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_333460/3325409998.py in <module>
# ----> 1 import fsleyes
#       2 overlayList, displayCtx, frame = fsleyes.embed()
#       3 frame.Show()
#
# ...

# %%
overlayList, displayCtx, _ = fsleyes.embed(mkFrame=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1388795/4266331710.py in <module>
# ----> 1 overlayList, displayCtx, _ = fsleyes.embed(mkFrame=False)
#
# NameError: name 'fsleyes' is not defined
